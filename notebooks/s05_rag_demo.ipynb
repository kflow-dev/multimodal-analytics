# %% [markdown]
# # RAG Anything — End-to-End Demo

# %% [markdown]
# ## Section S05 — End-to-End DemoComplete RAG pipeline: ingest → process → query → evaluate.

# %% [markdown]
# ### Step 1: Initialize Pipeline

# %%
from aifluent import AIFluent, AIFluentConfigconfig = AIFluentConfig()rag = AIFluent(config=config)print(f'Parser: {rag.config.parser}')print(f'Retriever: {rag.retriever.name}')

# %% [markdown]
# ### Step 2: Ingest Documents

# %%
# results = asyncio.run(rag.process_folder_complete("data/raw/"))

# %% [markdown]
# ### Step 3: Query the Pipeline

# %%
# result = asyncio.run(rag.aquery("What is this document about?", mode="mix"))

# %% [markdown]
# ### Step 4: Evaluate

# %%
# test_queries = [("query text", {"relevant_doc_ids"})]# eval_results = asyncio.run(rag.evaluate(test_queries, k_values=[1, 5, 10]))

# %% [markdown]
# ### Summary

# %%
print('=== RAG Anything Pipeline Summary ===')print(f'Parser:               {rag.config.parser}')print(f'Parse method:         {rag.config.parse_method}')print(f'Working directory:    {rag.config.working_dir}')print(f'Retriever:            {rag.retriever.name}')print(f'Reranker:             {type(rag.reranker).__name__}')print(f'Max concurrent files: {rag.config.max_concurrent_files}')
