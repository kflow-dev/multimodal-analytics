# %% [markdown]
# # RAG Anything — Evaluation

# %% [markdown]
# ## Section S04 — RAG EvaluationEvaluate retrieval quality using standard metrics (Precision@K, Recall@K, NDCG, MRR).

# %%
from evaluation import compute_metrics, Evaluatortest_queries = [    ("sample query text", {"doc1", "doc2"}),]k_values = [1, 5, 10]print(f'Evaluating {len(test_queries)} queries with k_values={k_values}')

# %% [markdown]
# ## Run Evaluation

# %%
from aifluent.retrieval.hybrid import HybridRetrieverretriever = HybridRetriever()evaluator = Evaluator()results = evaluator.evaluate(retriever, test_queries, k_values=k_values)evaluator.print_comparison(results)

# %% [markdown]
# ## Evaluate AIFluent Pipeline

# %%
# eval_results = asyncio.run(rag.evaluate(test_queries, k_values=[1, 5, 10]))# rag.print_evaluation_comparison(eval_results)# rag.save_evaluation_results("output/eval_results.json")
