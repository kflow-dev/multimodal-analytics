# %% [markdown]
# # RAG Anything — Multimodal Processing

# %% [markdown]
# ## Section S02 — Multimodal Content ProcessingDemonstrate image, table, and equation processing with context-aware analysis.

# %% [markdown]
# ## Image ProcessingImages are processed automatically during document ingestion when enable_image_processing=True in config.

# %% [markdown]
# ## Table ProcessingTables are extracted and analyzed with context awareness when enable_table_processing=True in config.

# %% [markdown]
# ## Equation ProcessingEquations are extracted and analyzed with context awareness when enable_equation_processing=True in config.

# %% [markdown]
# ## Context-Aware Processing

# %%
# Update context window for richer multimodal context# rag.update_context_config(context_window=2, context_mode="page")
